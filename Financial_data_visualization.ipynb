# %%
pip install yfinance
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import yfinance as yf

# %%
#import symbol
symbols = ["AAPL"	,"BA",	"DIS",	"IBM",	"KO",	"MSFT"]
stocks = yf.download(symbols, start="2009-01-01", end="2024-03-03")
# Out:
# [*********************100%***********************]  6 of 6 completed

# %%
stocks.head()
# Out:
#            Adj Close                                                         \
#                 AAPL         BA        DIS        IBM         KO       MSFT
# Date
# 2009-01-02  2.740173  33.941093  20.530582  49.160141  14.269995  15.011642
# 2009-01-05  2.855819  34.631165  20.170097  48.850662  14.126982  15.151940
# 2009-01-06  2.808715  34.736187  20.865326  50.206707  13.900027  15.329154
# 2009-01-07  2.748024  33.573555  19.895439  49.396446  13.968426  14.406158
# 2009-01-08  2.799052  33.596050  19.655115  49.053219  14.064806  14.856582
#
#                Close                                   ...       Open  \
#                 AAPL         BA        DIS        IBM  ...        DIS
# Date                                                   ...
# 2009-01-02  3.241071  45.250000  23.920000  83.527725  ...  22.760000
# 2009-01-05  3.377857  46.169998  23.500000  83.001915  ...  23.510000
# 2009-01-06  3.322143  46.310001  24.309999  85.305923  ...  23.809999
# ...

# %%
stocks.head()
# Out:
#            Adj Close                                                         \
#                 AAPL         BA        DIS        IBM         KO       MSFT
# Date
# 2009-01-02  2.740173  33.941093  20.530582  49.160141  14.269995  15.011642
# 2009-01-05  2.855819  34.631165  20.170097  48.850662  14.126982  15.151940
# 2009-01-06  2.808715  34.736187  20.865326  50.206707  13.900027  15.329154
# 2009-01-07  2.748024  33.573555  19.895439  49.396446  13.968426  14.406158
# 2009-01-08  2.799052  33.596050  19.655115  49.053219  14.064806  14.856582
#
#                Close                                   ...       Open  \
#                 AAPL         BA        DIS        IBM  ...        DIS
# Date                                                   ...
# 2009-01-02  3.241071  45.250000  23.920000  83.527725  ...  22.760000
# 2009-01-05  3.377857  46.169998  23.500000  83.001915  ...  23.510000
# 2009-01-06  3.322143  46.310001  24.309999  85.305923  ...  23.809999
# ...

# %%
stocks.tail()
# Out:
#              Adj Close                                                 \
#                   AAPL          BA         DIS         IBM         KO
# Date
# 2024-02-26  180.914627  200.539993  107.680000  182.320145  60.228252
# 2024-02-27  182.382629  201.399994  109.419998  183.052856  59.861187
# 2024-02-28  181.174255  207.000000  110.800003  183.478638  59.920715
# 2024-02-29  180.505173  203.720001  111.580002  183.211288  59.543728
# 2024-03-01  179.416656  200.000000  111.949997  186.350128  59.057613
#
#                              Close                                      ...  \
#                   MSFT        AAPL          BA         DIS         IBM  ...
# Date                                                                    ...
# 2024-02-26  406.806244  181.160004  200.539993  107.680000  184.130005  ...
# 2024-02-27  406.746338  182.630005  201.399994  109.419998  184.869995  ...
# 2024-02-28  406.985901  181.419998  207.000000  110.800003  185.300003  ...
# ...

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3816 entries, 2009-01-02 to 2024-03-01
# Data columns (total 36 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Adj Close, AAPL)  3816 non-null   float64
#  1   (Adj Close, BA)    3816 non-null   float64
#  2   (Adj Close, DIS)   3816 non-null   float64
#  3   (Adj Close, IBM)   3816 non-null   float64
#  4   (Adj Close, KO)    3816 non-null   float64
#  5   (Adj Close, MSFT)  3816 non-null   float64
#  6   (Close, AAPL)      3816 non-null   float64
#  7   (Close, BA)        3816 non-null   float64
#  8   (Close, DIS)       3816 non-null   float64
#  9   (Close, IBM)       3816 non-null   float64
#  10  (Close, KO)        3816 non-null   float64
#  11  (Close, MSFT)      3816 non-null   float64
#  12  (High, AAPL)       3816 non-null   float64
#  13  (High, BA)         3816 non-null   float64
#  14  (High, DIS)        3816 non-null   float64
# ...

# %%
close = stocks.loc[:, "Close"].copy()

# %%
close.head()
# Out:
#                 AAPL         BA        DIS        IBM         KO       MSFT
# Date
# 2009-01-02  3.241071  45.250000  23.920000  83.527725  22.950001  20.330000
# 2009-01-05  3.377857  46.169998  23.500000  83.001915  22.719999  20.520000
# 2009-01-06  3.322143  46.310001  24.309999  85.305923  22.355000  20.760000
# 2009-01-07  3.250357  44.759998  23.180000  83.929253  22.465000  19.510000
# 2009-01-08  3.310714  44.790001  22.900000  83.346077  22.620001  20.120001

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use("seaborn")
# Out:
# /tmp/ipykernel_2256020/715908909.py:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %%
close.plot(figsize = (15, 8), fontsize = 13)
plt.legend(fontsize = 13)
plt.show()

# %%
close.head()
# Out:
#                 AAPL         BA        DIS        IBM         KO       MSFT
# Date
# 2009-01-02  3.241071  45.250000  23.920000  83.527725  22.950001  20.330000
# 2009-01-05  3.377857  46.169998  23.500000  83.001915  22.719999  20.520000
# 2009-01-06  3.322143  46.310001  24.309999  85.305923  22.355000  20.760000
# 2009-01-07  3.250357  44.759998  23.180000  83.929253  22.465000  19.510000
# 2009-01-08  3.310714  44.790001  22.900000  83.346077  22.620001  20.120001

# %%
close.iloc[0,0]
# Out:
# 3.2410709857940674

# %%
close.AAPL.div(close.iloc[0,0]).mul(100)
# Out:
# Date
# 2009-01-02     100.000000
# 2009-01-05     104.220395
# 2009-01-06     102.501398
# 2009-01-07     100.286508
# 2009-01-08     102.148766
#                  ...
# 2024-02-26    5589.510518
# 2024-02-27    5634.865934
# 2024-02-28    5597.532389
# 2024-02-29    5576.860266
# 2024-03-01    5543.229520
# Name: AAPL, Length: 3816, dtype: float64

# %%
close.iloc[0]
# Out:
# AAPL     3.241071
# BA      45.250000
# DIS     23.920000
# IBM     83.527725
# KO      22.950001
# MSFT    20.330000
# Name: 2009-01-02 00:00:00, dtype: float64

# %%
norm = close.div(close.iloc[0]).mul(100)
norm
# Out:
#                    AAPL          BA         DIS         IBM          KO  \
# Date
# 2009-01-02   100.000000  100.000000  100.000000  100.000000  100.000000
# 2009-01-05   104.220395  102.033145   98.244147   99.370496   98.997815
# 2009-01-06   102.501398  102.342544  101.630432  102.128872   97.407402
# 2009-01-07   100.286508   98.917123   96.906355  100.480712   97.886708
# 2009-01-08   102.148766   98.983427   95.735784   99.782529   98.562092
# ...                 ...         ...         ...         ...         ...
# 2024-02-26  5589.510518  443.182306  450.167224  220.441781  264.531578
# 2024-02-27  5634.865934  445.082859  457.441462  221.327702  262.919382
# 2024-02-28  5597.532389  457.458564  463.210714  221.842511  263.180826
# 2024-02-29  5576.860266  450.209947  466.471578  221.519260  261.525048
# 2024-03-01  5543.229520  441.988950  468.018380  225.314405  259.389964
#
#                    MSFT
# Date
# 2009-01-02   100.000000
# 2009-01-05   100.934582
# ...

# %%
norm.plot(figsize = (15,8), fontsize = 13)
plt.legend(fontsize = 13)
plt.show()

# %%
aapl = close.AAPL.copy().to_frame()

# %%
aapl.head()
# Out:
#                 AAPL
# Date
# 2009-01-02  3.241071
# 2009-01-05  3.377857
# 2009-01-06  3.322143
# 2009-01-07  3.250357
# 2009-01-08  3.310714

# %%
aapl.AAPL.diff(periods = 1)
# Out:
# Date
# 2009-01-02         NaN
# 2009-01-05    0.136786
# 2009-01-06   -0.055714
# 2009-01-07   -0.071786
# 2009-01-08    0.060357
#                 ...
# 2024-02-26   -1.360001
# 2024-02-27    1.470001
# 2024-02-28   -1.210007
# 2024-02-29   -0.669998
# 2024-03-01   -1.089996
# Name: AAPL, Length: 3816, dtype: float64

# %%
aapl["Diff2"] = aapl.AAPL.diff(periods = 1)

# %%
aapl.head(10)
# Out:
#                 AAPL     Diff2
# Date
# 2009-01-02  3.241071       NaN
# 2009-01-05  3.377857  0.136786
# 2009-01-06  3.322143 -0.055714
# 2009-01-07  3.250357 -0.071786
# 2009-01-08  3.310714  0.060357
# 2009-01-09  3.235000 -0.075714
# 2009-01-12  3.166429 -0.068571
# 2009-01-13  3.132500 -0.033929
# 2009-01-14  3.047500 -0.085000
# 2009-01-15  2.977857 -0.069643

# %%
aapl["pct_change2"] = aapl.AAPL.pct_change(periods = 1).mul(100)

# %%
aapl.head()
# Out:
#                 AAPL     Diff2  pct_change2
# Date
# 2009-01-02  3.241071       NaN          NaN
# 2009-01-05  3.377857  0.136786     4.220395
# 2009-01-06  3.322143 -0.055714    -1.649386
# 2009-01-07  3.250357 -0.071786    -2.160839
# 2009-01-08  3.310714  0.060357     1.856937

# %%
aapl.AAPL.resample("BM").last().pct_change(periods = 1).mul(100)
# Out:
# Date
# 2009-01-30          NaN
# 2009-02-27    -0.909810
# 2009-03-31    17.702394
# 2009-04-30    19.701292
# 2009-05-29     7.931326
#                 ...
# 2023-11-30    11.231476
# 2023-12-29     1.358253
# 2024-01-31    -4.222721
# 2024-02-29    -1.979389
# 2024-03-29    -0.603041
# Freq: BM, Name: AAPL, Length: 183, dtype: float64

# %%
aapl.pct_change().dropna()
# Out:
#                 AAPL     Diff2  pct_change2
# Date
# 2009-01-06 -0.016494 -1.407307    -1.390813
# 2009-01-07 -0.021608  0.288479     0.310087
# 2009-01-08  0.018569 -1.840790    -1.859359
# 2009-01-09 -0.022869 -2.254436    -2.231567
# 2009-01-12 -0.021197 -0.094345    -0.073149
# ...              ...       ...          ...
# 2024-02-26 -0.007451 -0.264861    -0.257410
# 2024-02-27  0.008114 -2.080883    -2.088997
# 2024-02-28 -0.006625 -1.823133    -1.816508
# 2024-02-29 -0.003693 -0.446286    -0.442592
# 2024-03-01 -0.006030  0.626865     0.632895
#
# [3814 rows x 3 columns]

# %%
ret = aapl.pct_change().dropna()
ret.head()
# Out:
#                 AAPL     Diff2  pct_change2
# Date
# 2009-01-06 -0.016494 -1.407307    -1.390813
# 2009-01-07 -0.021608  0.288479     0.310087
# 2009-01-08  0.018569 -1.840790    -1.859359
# 2009-01-09 -0.022869 -2.254436    -2.231567
# 2009-01-12 -0.021197 -0.094345    -0.073149

# %%
ret.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3814 entries, 2009-01-06 to 2024-03-01
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   AAPL         3814 non-null   float64
#  1   Diff2        3814 non-null   float64
#  2   pct_change2  3814 non-null   float64
# dtypes: float64(3)
# memory usage: 119.2 KB

# %%
ret.dropna().values
# Out:
# array([[-0.01649386, -1.40730702, -1.39081317],
#        [-0.02160839,  0.28847874,  0.31008713],
#        [ 0.01856937, -1.84079005, -1.85935943],
#        ...,
#        [-0.00662545, -1.82313314, -1.81650768],
#        [-0.00369308, -0.44628558, -0.4425925 ],
#        [-0.00603041,  0.62686465,  0.63289506]])

# %%
ret
# Out:
#                 AAPL     Diff2  pct_change2
# Date
# 2009-01-06 -0.016494 -1.407307    -1.390813
# 2009-01-07 -0.021608  0.288479     0.310087
# 2009-01-08  0.018569 -1.840790    -1.859359
# 2009-01-09 -0.022869 -2.254436    -2.231567
# 2009-01-12 -0.021197 -0.094345    -0.073149
# ...              ...       ...          ...
# 2024-02-26 -0.007451 -0.264861    -0.257410
# 2024-02-27  0.008114 -2.080883    -2.088997
# 2024-02-28 -0.006625 -1.823133    -1.816508
# 2024-02-29 -0.003693 -0.446286    -0.442592
# 2024-03-01 -0.006030  0.626865     0.632895
#
# [3814 rows x 3 columns]

# %%
ret = ret[np.isfinite(ret).all(1)]
ret
# Out:
#                 AAPL     Diff2  pct_change2
# Date
# 2009-01-06 -0.016494 -1.407307    -1.390813
# 2009-01-07 -0.021608  0.288479     0.310087
# 2009-01-08  0.018569 -1.840790    -1.859359
# 2009-01-09 -0.022869 -2.254436    -2.231567
# 2009-01-12 -0.021197 -0.094345    -0.073149
# ...              ...       ...          ...
# 2024-02-26 -0.007451 -0.264861    -0.257410
# 2024-02-27  0.008114 -2.080883    -2.088997
# 2024-02-28 -0.006625 -1.823133    -1.816508
# 2024-02-29 -0.003693 -0.446286    -0.442592
# 2024-03-01 -0.006030  0.626865     0.632895
#
# [3807 rows x 3 columns]

# %%
ret =ret.drop(['Diff2', 'pct_change2'], axis=1)

# %%
ret.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3807 entries, 2009-01-06 to 2024-03-01
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AAPL    3807 non-null   float64
# dtypes: float64(1)
# memory usage: 59.5 KB

# %%
ret.plot(kind = "hist", figsize = (12, 8), bins = 100)
plt.show()

# %%
daily_mean_Return = ret.mean()
daily_mean_Return
# Out:
# AAPL    0.001209
# dtype: float64

# %%
var_daily_Returns = ret.var()
var_daily_Returns
# Out:
# AAPL    0.000322
# dtype: float64

# %%
std_daily_Retruns = np.sqrt(var_daily_Returns)
std_daily_Retruns
# Out:
# AAPL    0.017952
# dtype: float64

# %%
ann_mean_Returns = ret.mean() * 252
ann_mean_Returns
# Out:
# AAPL    0.304765
# dtype: float64

# %%
ann_var_Returns = ret.var() * 252
ann_var_Returns
# Out:
# AAPL    0.08121
# dtype: float64

# %%
ann_std_Returns = np.sqrt(ann_var_Returns)
ann_std_Returns
# Out:
# AAPL    0.284974
# dtype: float64

# %%
norm.plot(figsize = (15, 8), fontsize = 13)
plt.legend(fontsize = 13)
plt.show()

# %%
close.pct_change()
# Out:
#                 AAPL        BA       DIS       IBM        KO      MSFT
# Date
# 2009-01-02       NaN       NaN       NaN       NaN       NaN       NaN
# 2009-01-05  0.042204  0.020331 -0.017559 -0.006295 -0.010022  0.009346
# 2009-01-06 -0.016494  0.003032  0.034468  0.027758 -0.016065  0.011696
# 2009-01-07 -0.021608 -0.033470 -0.046483 -0.016138  0.004921 -0.060212
# 2009-01-08  0.018569  0.000670 -0.012079 -0.006948  0.006900  0.031266
# ...              ...       ...       ...       ...       ...       ...
# 2024-02-26 -0.007451 -0.001444 -0.000557 -0.008561 -0.008007 -0.006824
# 2024-02-27  0.008114  0.004288  0.016159  0.004019 -0.006095 -0.000147
# 2024-02-28 -0.006625  0.027805  0.012612  0.002326  0.000994  0.000589
# 2024-02-29 -0.003693 -0.015845  0.007040 -0.001457 -0.006291  0.014520
# 2024-03-01 -0.006030 -0.018260  0.003316  0.017132 -0.008164  0.004497
#
# [3816 rows x 6 columns]

# %%
ret = close.pct_change().dropna()

# %%
ret.head()
# Out:
#                 AAPL        BA       DIS       IBM        KO      MSFT
# Date
# 2009-01-05  0.042204  0.020331 -0.017559 -0.006295 -0.010022  0.009346
# 2009-01-06 -0.016494  0.003032  0.034468  0.027758 -0.016065  0.011696
# 2009-01-07 -0.021608 -0.033470 -0.046483 -0.016138  0.004921 -0.060212
# 2009-01-08  0.018569  0.000670 -0.012079 -0.006948  0.006900  0.031266
# 2009-01-09 -0.022869 -0.007591 -0.025764 -0.028447 -0.014147 -0.029821

# %%
ret.describe().T.loc[:, ["mean", "std"]]
# Out:
#           mean       std
# AAPL  0.001214  0.017964
# BA    0.000651  0.022837
# DIS   0.000552  0.017218
# IBM   0.000316  0.014317
# KO    0.000312  0.011135
# MSFT  0.000933  0.016853

# %%
summary = ret.describe().T.loc[:, ["mean", "std"]]
summary
# Out:
#           mean       std
# AAPL  0.001214  0.017964
# BA    0.000651  0.022837
# DIS   0.000552  0.017218
# IBM   0.000316  0.014317
# KO    0.000312  0.011135
# MSFT  0.000933  0.016853

# %%
summary["mean"] = summary["mean"]*252
summary["std"] = summary["std"] * np.sqrt(252)

# %%
summary
# Out:
#           mean       std
# AAPL  0.306016  0.285173
# BA    0.163982  0.362524
# DIS   0.139198  0.273329
# IBM   0.079558  0.227269
# KO    0.078646  0.176759
# MSFT  0.235177  0.267535

# %%
summary.plot.scatter(x = "std", y = "mean", figsize =(12,8), s = 50, fontsize = 15)
for i in summary.index:
  plt.annotate(i, xy= (summary.loc[i, "std"] + 0.002, summary.loc[i, "mean"] + 0.002), size = 15)
plt.xlabel("ann. Risk(std)", fontsize = 15)
plt.ylabel("ann. Return", fontsize = 15)
plt.title("Risk/Return", fontsize = 20)
plt.show()

# %%
ret.head()
# Out:
#                 AAPL        BA       DIS       IBM        KO      MSFT
# Date
# 2009-01-05  0.042204  0.020331 -0.017559 -0.006295 -0.010022  0.009346
# 2009-01-06 -0.016494  0.003032  0.034468  0.027758 -0.016065  0.011696
# 2009-01-07 -0.021608 -0.033470 -0.046483 -0.016138  0.004921 -0.060212
# 2009-01-08  0.018569  0.000670 -0.012079 -0.006948  0.006900  0.031266
# 2009-01-09 -0.022869 -0.007591 -0.025764 -0.028447 -0.014147 -0.029821

# %%
ret.cov()
# Out:
#           AAPL        BA       DIS       IBM        KO      MSFT
# AAPL  0.000323  0.000164  0.000130  0.000108  0.000068  0.000173
# BA    0.000164  0.000522  0.000202  0.000144  0.000105  0.000152
# DIS   0.000130  0.000202  0.000296  0.000109  0.000083  0.000137
# IBM   0.000108  0.000144  0.000109  0.000205  0.000073  0.000112
# KO    0.000068  0.000105  0.000083  0.000073  0.000124  0.000075
# MSFT  0.000173  0.000152  0.000137  0.000112  0.000075  0.000284

# %%
ret.corr()
# Out:
#           AAPL        BA       DIS       IBM        KO      MSFT
# AAPL  1.000000  0.399571  0.421397  0.420671  0.341561  0.572197
# BA    0.399571  1.000000  0.513135  0.440962  0.411767  0.395414
# DIS   0.421397  0.513135  1.000000  0.442521  0.435084  0.470618
# IBM   0.420671  0.440962  0.442521  1.000000  0.460364  0.465311
# KO    0.341561  0.411767  0.435084  0.460364  1.000000  0.400623
# MSFT  0.572197  0.395414  0.470618  0.465311  0.400623  1.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize = (12,8))
sns.set(font_scale=1.4)
sns.heatmap(ret.corr(), cmap = "Reds", annot = True, annot_kws = {"size":15}, vmax = 0.6)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("seaborn")
# Out:
# /tmp/ipykernel_2256020/1123596123.py:4: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %%
stocks = stocks.loc["31-12-2015":"31-12-2023", "Adj Close"]

# %%
stocks.head()
# Out:
#                  AAPL          BA        DIS        IBM         KO       MSFT
# Date
# 2015-12-31  23.894058  129.673141  98.814964  89.743256  33.021652  49.123562
# 2016-01-04  23.914480  126.005066  96.840172  88.654236  32.591190  48.521481
# 2016-01-05  23.315203  126.516319  94.884186  88.589043  32.706505  48.742836
# 2016-01-06  22.858931  124.507408  94.376381  88.145607  32.529701  47.857407
# 2016-01-07  21.894180  119.287827  93.567642  86.639236  31.991642  46.192795

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2013 entries, 2015-12-31 to 2023-12-29
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AAPL    2013 non-null   float64
#  1   BA      2013 non-null   float64
#  2   DIS     2013 non-null   float64
#  3   IBM     2013 non-null   float64
#  4   KO      2013 non-null   float64
#  5   MSFT    2013 non-null   float64
# dtypes: float64(6)
# memory usage: 110.1 KB

# %%
stocks.plot(figsize = (12, 8))
plt.show()

# %%
stocks.div(stocks.iloc[0]).mul(100).plot(figsize = (12,8))
plt.show()

# %%
stocks_m = stocks.resample("M").last()

# %%
stocks_m.head()
# Out:
#                  AAPL          BA        DIS        IBM         KO       MSFT
# Date
# 2015-12-31  23.894058  129.673141  98.814964  89.743256  33.021652  49.123562
# 2016-01-31  22.096209  107.736618  90.107056  81.376709  32.990898  48.778252
# 2016-02-29  22.067762  106.968575  89.824944  86.318642  33.152309  45.374050
# 2016-03-31  24.875013  114.897545  93.388985  99.770752  35.936234  49.253319
# 2016-04-30  21.394470  122.011879  97.103470  96.140915  34.704529  44.473347

# %%
ret = stocks_m.pct_change().dropna()
ret
# Out:
#                 AAPL        BA       DIS       IBM        KO      MSFT
# Date
# 2016-01-31 -0.075243 -0.169168 -0.088123 -0.093228 -0.000931 -0.007029
# 2016-02-29 -0.001287 -0.007129 -0.003131  0.060729  0.004893 -0.069789
# 2016-03-31  0.127210  0.074124  0.039678  0.155842  0.083974  0.085495
# 2016-04-30 -0.139921  0.061919  0.039774 -0.036382 -0.034275 -0.097049
# 2016-05-31  0.071773 -0.056536 -0.039125  0.063613 -0.004464  0.070197
# ...              ...       ...       ...       ...       ...       ...
# 2023-08-31 -0.042384 -0.062047 -0.058612  0.030099 -0.033909 -0.022226
# 2023-09-30 -0.088678 -0.144400 -0.031429 -0.044473 -0.056926 -0.036643
# 2023-10-31 -0.002570 -0.025355  0.006662  0.030934  0.009110  0.070815
# 2023-11-30  0.113780  0.239857  0.136046  0.108672  0.042757  0.122946
# 2023-12-31  0.013583  0.125329 -0.022718  0.031471  0.008385 -0.007574
#
# [96 rows x 6 columns]

# %%
summary = ret.agg(["mean", "std"]).T
summary
# Out:
#           mean       std
# AAPL  0.025395  0.083962
# BA    0.014578  0.119430
# DIS   0.002510  0.084388
# IBM   0.008404  0.068376
# KO    0.007080  0.046942
# MSFT  0.023077  0.058965

# %%
summary["mean"] = summary["mean"]*12
summary["std"]  = summary["std"]*np.sqrt(12)

# %%
summary.plot(kind = "scatter", x = "std", y = "mean", figsize =(12,8), s = 50, fontsize = 15, xlim= False)
for i in summary.index:
  plt.annotate(i, xy= (summary.loc[i, "std"] + 0.002, summary.loc[i, "mean"] + 0.002), size = 15)
plt.xlabel("ann. Risk(std)", fontsize = 15)
plt.ylabel("ann. Return", fontsize = 15)
plt.title("Risk/Return", fontsize = 20)
plt.show()

# %%
ret.corr()
# Out:
#           AAPL        BA       DIS       IBM        KO      MSFT
# AAPL  1.000000  0.287168  0.425561  0.329029  0.272429  0.675728
# BA    0.287168  1.000000  0.486977  0.435946  0.401789  0.345688
# DIS   0.425561  0.486977  1.000000  0.288011  0.437946  0.397637
# IBM   0.329029  0.435946  0.288011  1.000000  0.428629  0.329607
# KO    0.272429  0.401789  0.437946  0.428629  1.000000  0.339552
# MSFT  0.675728  0.345688  0.397637  0.329607  0.339552  1.000000

# %%
plt.figure(figsize =(12, 8))
sns.set(font_scale=1.0)
sns.heatmap(ret.corr(), cmap = "RdYlGn", annot = True, vmin = -0.5, vmax = 0.6, center = 0)
plt.show()
